# %%
#Use Exclamatory matk before pip
# !pip install pandas
# !pip install numpy 
# !pip install matplotlib 
# !pip install seaborn

# %%
import numpy as np # Help to works on array (mathematically).
import pandas as pd # Help to work on tables or spreadsheets.
import matplotlib.pyplot as plt # Help in visualizing data.
import seaborn as sns # Same as matplotlib (Used for Charts, Graphs, etc).

# %%
df = pd.read_csv('waterquality.csv', encoding = 'unicode_escape') # We can able to read a csv file in python using pd(pandas).
'''If csv file 
is not in the main folder(near .ipynb file is situated) it will produce UTF-8 encoded error, for the error to solve
we use encoding = 'unicode_escape'.'''
# Out:
# "If csv file \nis not in the main folder(near .ipynb file is situated) it will produce UTF-8 encoded error, for the error to solve\nwe use encoding = 'unicode_escape'."

# %%
#It will tell the number of rows and column in csv file.
df.shape
# Out:
# (534, 11)

# %%
df.head(7) #It will show 5 rows by default from the top but here it will show 7 rows.
# Out:
#    STATION CODE                                          LOCATIONS  \
# 0          1312  GODAVARI AT JAYAKWADI DAM, AURNAGABAD,MAHARASHTRA
# 1          2177              GODAVARI RIVER NEAR SOMESHWAR TEMPLE.
# 2          2182                        GODAVARI RIVER AT SAIKHEDA.
# 3          2179       GODAVARI RIVER AT HANUMAN GHAT, NASHIK CITY.
# 4          2183          GODAVARI RIVER AT NANDUR- MADMESHWAR DAM.
# 5          2181  GODAVARI RIVER AT KAPILA- GODAVARI CONFLUENCE ...
# 6          2180                       GODAVARI RIVER NEAR TAPOVAN.
#
#          STATE  TEMP   DO   pH  CONDUCTIVITY   BOD  NITRATE_N_NITRITE_N  \
# 0  MAHARASHTRA  29.2  6.4  8.1         735.0   3.4                 2.00
# 1  MAHARASHTRA  24.5  6.0  8.0         270.0   3.1                 2.00
# 2  MAHARASHTRA  25.8  5.5  7.8         355.0   4.2                 9.00
# 3  MAHARASHTRA  24.8  5.5  7.8         371.0   5.6                 3.55
# ...

# %%
df.tail(7) #It will show 5 rows by default from the bottom but here it will show 7 rows.
# Out:
#      STATION CODE                                          LOCATIONS  \
# 527          2938  LAKE RAJSAMAND, RAJSAMAND- POINT NO. 1, RAJSAM...
# 528          2939  LAKE RAJSAMAND, RAJSAMAND- POINT NO. 2, RAJSAM...
# 529          2940             GAPE- SAGAR LAKE, DUNGARPUR, RAJASTHAN
# 530          2941  LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 1...
# 531          2942  LAKE JAISAMAND, SALUMBER, UDAIPUR, POINT NO. 2...
# 532          2943  LODHA TALAB, BANSWARA- DUNGARPUR ROAD, BANSWAR...
# 533          2944                        JALMAHAL, JAIPUR, RAJASTHAN
#
#          STATE  TEMP   DO   pH  CONDUCTIVITY  BOD  NITRATE_N_NITRITE_N  \
# 527  RAJASTHAN  21.3  5.0  8.6         604.0  1.2                 2.29
# 528  RAJASTHAN  21.2  4.9  8.6         593.0  1.1                 1.00
# 529  RAJASTHAN  23.2  4.4  8.1         538.0  1.2                 1.00
# 530  RAJASTHAN  22.9  5.6  8.4         591.0  1.1                 3.00
# ...

# %%
df.info() #It will give information of CSV file data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   STATION CODE         534 non-null    int64
#  1   LOCATIONS            534 non-null    object
#  2   STATE                534 non-null    object
#  3   TEMP                 529 non-null    float64
#  4   DO                   532 non-null    float64
#  5   pH                   534 non-null    float64
#  6   CONDUCTIVITY         504 non-null    float64
#  7   BOD                  528 non-null    float64
#  8   NITRATE_N_NITRITE_N  532 non-null    float64
#  9   FECAL_COLIFORM       452 non-null    float64
#  10  TOTAL_COLIFORM       495 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 46.0+ KB

# %%
''' If we want to remove any column from the csv file we use the command {df.drop(['clmname1','clmname2'], axis=1, inplace=true)}
here axis=1 means the whole column and inplace=true will save the work done '''
# Out:
# " If we want to remove any column from the csv file we use the command {df.drop(['clmname1','clmname2'], axis=1, inplace=true)}\nhere axis=1 means the whole column and inplace=true will save the work done "

# %%
pd.isnull(df) # If there is any null value it will show as true otherwise false.
# Out:
#      STATION CODE  LOCATIONS  STATE   TEMP     DO     pH  CONDUCTIVITY    BOD  \
# 0           False      False  False  False  False  False         False  False
# 1           False      False  False  False  False  False         False  False
# 2           False      False  False  False  False  False         False  False
# 3           False      False  False  False  False  False         False  False
# 4           False      False  False  False  False  False         False  False
# ..            ...        ...    ...    ...    ...    ...           ...    ...
# 529         False      False  False  False  False  False         False  False
# 530         False      False  False  False  False  False         False  False
# 531         False      False  False  False  False  False         False  False
# 532         False      False  False  False  False  False         False  False
# 533         False      False  False  False  False  False         False  False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# STATION CODE            0
# LOCATIONS               0
# STATE                   0
# TEMP                    5
# DO                      2
# pH                      0
# CONDUCTIVITY           30
# BOD                     6
# NITRATE_N_NITRITE_N     2
# FECAL_COLIFORM         82
# TOTAL_COLIFORM         39
# dtype: int64

# %%
df.dropna(inplace = True) #It will drop the null values from DataFrame and save the file.

# %%
df.shape
# Out:
# (447, 11)

# %%
pd.isnull(df).sum()
# Out:
# STATION CODE           0
# LOCATIONS              0
# STATE                  0
# TEMP                   0
# DO                     0
# pH                     0
# CONDUCTIVITY           0
# BOD                    0
# NITRATE_N_NITRITE_N    0
# FECAL_COLIFORM         0
# TOTAL_COLIFORM         0
# dtype: int64

# %%
df.columns #It will show the all possible columns.
# Out:
# Index(['STATION CODE', 'LOCATIONS', 'STATE', 'TEMP', 'DO', 'pH',
#        'CONDUCTIVITY', 'BOD', 'NITRATE_N_NITRITE_N', 'FECAL_COLIFORM',
#        'TOTAL_COLIFORM'],
#       dtype='object')

# %%
df.describe() #It will describe the count, mean and other details of csv file.
# Out:
#        STATION CODE        TEMP          DO          pH  CONDUCTIVITY  \
# count    447.000000  447.000000  447.000000  447.000000    447.000000
# mean    2056.619687   25.498434    6.444362    7.813423    625.794183
# std      750.601339    3.311283    1.497170    0.689608   1772.173138
# min       11.000000   10.500000    0.000000    6.300000     39.000000
# 25%     1354.500000   23.400000    5.600000    7.500000    267.500000
# 50%     2173.000000   25.700000    6.600000    7.900000    366.000000
# 75%     2662.500000   27.800000    7.500000    8.100000    539.500000
# max     3330.000000   33.800000   16.300000   14.700000  24062.000000
#
#               BOD  NITRATE_N_NITRITE_N  FECAL_COLIFORM  TOTAL_COLIFORM
# count  447.000000           447.000000      447.000000      447.000000
# mean     4.638031             1.414899     6720.398210    15049.494407
# std      6.388326             2.924047    28567.158563    57767.357896
# ...

# %%
df[['DO','pH']].describe() #It will describe for particular columns only.
# Out:
#                DO          pH
# count  532.000000  534.000000
# mean     6.389812    7.798127
# std      1.622862    0.649950
# min      0.000000    6.300000
# 25%      5.575000    7.500000
# 50%      6.700000    7.900000
# 75%      7.425000    8.100000
# max     16.300000   14.700000

# %%
DO = df['DO']
BOD = df['BOD']
sns.set(rc={'figure.figsize':(10,5)})
plt.scatter(DO, BOD)

# %%
df_fil = df.head(30)
ua = sns.countplot(x = 'NITRATE_N_NITRITE_N', data = df_fil)
sns.set(rc={'figure.figsize':(15,5)})
for bars in ua.containers:
    ua.bar_label(bars)

# %%
print(' maximum bodies have 0 nitrates and nitrites')
# Out:
#  maximum bodies have 0 nitrates and nitrites

# %%
vv = sns.countplot(x = 'pH', data = df)
sns.set(rc={'figure.figsize':(15,5)})
for bars in vv.containers:
    vv.bar_label(bars)

# %%
df_fil = df.head(25)
va = sns.countplot(x = 'CONDUCTIVITY', data = df_fil)
sns.set(rc={'figure.figsize':(15,5)})
for bars in va.containers:
    va.bar_label(bars)

# %%
print('Here from the above graph , we able to get to know about most of the River bodies are under pH Range.')
print('Therefore, these bodies are well suited to living aquatic organisms.')
# Out:
# Here from the above graph , we able to get to know about most of the River bodies are under pH Range.
# Therefore, these bodies are well suited to living aquatic organisms.

# %%
df_fil = df.head(30)
vu = sns.countplot(x = 'BOD', data = df_fil)
sns.set(rc={'figure.figsize':(1,5)})
for bars in vu.containers:
    vu.bar_label(bars)

# %%
print('Therefore, The river bodies greater than 5 is somehow polluted.')
print('Aquatic animals in these rivers are struggling to live.')
# Out:
# Therefore, The river bodies greater than 5 is somehow polluted.
# Aquatic animals in these rivers are struggling to live.

# %%
df_fil = df.head(25)
va = sns.countplot(x = 'TOTAL_COLIFORM', data = df_fil)
sns.set(rc={'figure.figsize':(15,5)})
for bars in va.containers:
    va.bar_label(bars)

# %%
df_fil = df.head(30)
uv = sns.countplot(x = 'TEMP', data = df_fil)
sns.set(rc={'figure.figsize':(15,5)})
for bars in uv.containers:
    uv.bar_label(bars)

# %%
print('Maximum temperature is 29.5 degree celcius by 3 water bodies.')
print('Average range of temperature should be between 22 - 25 degree celsius.')
# Out:
# Maximum temperature is 29.5 degree celcius by 3 water bodies.
# Average range of temperature should be between 22 - 25 degree celsius.

# %%
marine = df.groupby(['pH'], as_index=False)['DO'].sum().sort_values(by = 'DO', ascending=False)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x = 'pH' ,y='DO', data = marine)
# Out:
# <Axes: xlabel='pH', ylabel='DO'>

# %%
sns.countplot(data = df, x = 'pH')
sns.set(rc={'figure.figsize':(20,5)})

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20, 20));

# %%
# Pairplot
sns.pairplot(data = df)
plt.show()

# %%
dataa = df.groupby(['DO'], as_index = False)['BOD'].sum().sort_values(by = 'BOD', ascending = False).head(20)
sns.set(rc={'figure.figsize':(25,5)})
sns.barplot(x = 'DO', y = 'BOD', data = dataa)
# Out:
# <Axes: xlabel='DO', ylabel='BOD'>

# %%
dataa = df.groupby(['STATION CODE'], as_index = False)['TEMP'].sum().sort_values(by = 'TEMP', ascending = False).head(25)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x = 'STATION CODE', y = 'TEMP', data = dataa)
# Out:
# <Axes: xlabel='STATION CODE', ylabel='TEMP'>

# %%
df_filtered = df.head(25)
sns.set(rc = {'figure.figsize':(15,5)})
ax = sns.countplot(data = df_filtered, x = 'TOTAL_COLIFORM')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
TOTAL_COLIFORM  = df['TOTAL_COLIFORM']
FECAL_COLIFORM = df['FECAL_COLIFORM']
sns.set(rc={'figure.figsize':(10,5)})
plt.scatter(TOTAL_COLIFORM, FECAL_COLIFORM)

# %%
ana = df.groupby(['pH'], as_index = False)['TEMP'].sum().sort_values(by = 'TEMP', ascending = False).head(20)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = ana, x = 'pH', y = 'TEMP')
# Out:
# <Axes: xlabel='pH', ylabel='TEMP'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 20)

# %%
X_train
# Out:
#      STATION CODE                                          LOCATIONS  \
# 261          2575               SIKRAHNA RIVER AT LAL PARSE, BITTIAH
# 18           2361  GODAVARI  AT MANCHERIAL, NEAR RLY BDG B/C OF R...
# 421          2700  PURNA RIVER NEAR ACHALPUR-AMRAVATI ROAD BRIDGE...
# 428          2662  DARNA RIVER AT MES SITE PUMPING STATION, BHAGU...
# 89           2506                TRIBENI ON GANGA, NEAR BURNING GHAT
# ..            ...                                                ...
# 218          2239                              SANKOSH RIVER, DHUBRI
# 223          2524  KALJANI D/S OF ALIPURDWAR, MUNICIPALITY DISCHA...
# 271          2565                 KOSHI RIVER AT KURSHELA AT KATIHAR
# 474          3176                                        RUMDER LAKE
# 355          1192          BHIMA AFTER CONF. WITH DAUNT, MAHARASHTRA
#
#               STATE  TEMP   pH  CONDUCTIVITY   BOD  NITRATE_N_NITRITE_N  \
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.neighbors import KNeighborsClassifier
#       2 knn = KNeighborsClassifier()
#       3 knn.fit(X_train, y_train)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2,random_state=7)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 X_train, X_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2,random_state=7)
#
# ModuleNotFoundError: No module named 'sklearn'
